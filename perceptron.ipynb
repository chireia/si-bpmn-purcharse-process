# %% [markdown]
# <a href="https://colab.research.google.com/github/ebasantos/BPMN/blob/master/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
entradas = [0.56, 0.29, 0.19];
baseA = [0.89, 0.7, 0.7]
baseB = [0.5, 0.19, 0.18];
baseC = [0.18, 0.56, 0.84];
i = 0;
for entrada in entradas:
  if(i == 0):
    for base in baseA:
      primeiroCalculo = entrada * base
      ##f(x) = x + 0.3
      calculoFinal = primeiroCalculo + 0.3
      print("Resultado = ", calculoFinal)
  elif(i == 1):
    for base in baseB:
      primeiroCalculo = entrada * base
      ##f(x) = x + 0.3
      calculoFinal = primeiroCalculo + 0.3
      print("Resultado = ", calculoFinal)
  elif(i == 2):
    for base in baseC:
      primeiroCalculo = entrada * base
      ##f(x) = x + 0.3
      calculoFinal = primeiroCalculo + 0.3
      print("Resultado = ", calculoFinal)
  i = i+1;
# Out:
# Resultado =  0.7984
# Resultado =  0.692
# Resultado =  0.692
# Resultado =  0.44499999999999995
# Resultado =  0.35509999999999997
# Resultado =  0.35219999999999996
# Resultado =  0.3342
# Resultado =  0.4064
# Resultado =  0.4596
